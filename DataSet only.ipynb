# %% [markdown]
# # Etapa 1: Importação das bibliotecas

# %%
# Importing the necessary libraries:
import torch
from torch import nn, optim
import math
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from sklearn.preprocessing import MinMaxScaler    # Biblioteca para transformar os dados a escala ente 0-1 
import matplotlib.pyplot as plt
from sklearn.metrics import mean_absolute_error
torch.__version__
torch.manual_seed(123)

# %% [markdown]
# ## Etapa 2: Importação Base de dados

# %%
Dt = pd.read_csv("DATA_SET_SOLAR/df_sem_outliers.csv",index_col=0,header=0, names=['solar_irradiation(w/m²)'])
## 3.1 apagando linhas NAN
Dt = Dt.dropna()
Dt=Dt[Dt["solar_irradiation(w/m²)"]>=1]
Dado_solar=Dt[["solar_irradiation(w/m²)"]].values
np.shape(Dado_solar)
# Out:
# (4632, 1)

# %%
ls -ltr
# Out:
# total 32
# drwxrwx--- 2 rodrigo rodrigo 4096 mai 23  2022  Imagens_preporcess/
# drwxrwx--- 3 rodrigo rodrigo 4096 jun 21  2022  Resultados_fGAN/
# drwxrwxr-x 4 rodrigo rodrigo 4096 jun 24  2022  Resultados_iniciais_PseudfGAN_MLP/
# drwxrwxr-x 4 rodrigo rodrigo 4096 jun 24  2022  Resultados_iniciais_fGAN_full/
# drwxrwx--- 4 rodrigo rodrigo 4096 jul  6 19:27  Imagens_final/
# -rw-rw-r-- 1 rodrigo rodrigo   72 dez 28 21:42  README.md
# -rw-rw-r-- 1 rodrigo rodrigo 3672 dez 28 21:45 'DataSet only.ipynb'
# drwxrwxr-x 2 rodrigo rodrigo 4096 dez 28 21:45  DATA_SET_SOLAR/

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 16,4
plt.plot(Dado_solar[-200:])
#plt.plot(zer[:],Dado_senoide[0], ".")
